# %%
# %load_ext autoreload
# %autoreload 2
# %load_ext line_profiler

# %%
import pandas as pd 
from travis_attack.utils import display_all

# %%
filename_results = f"/data/tproth/travis_attack/baselines/results.csv"
df_results = pd.read_csv(filename_results)
df_results[['date', 'time']] = df_results['datetime'].str.split('_', 1, expand=True)
first_cols = ['datetime','date','time']
last_cols = [col for col in df_results.columns if col not in first_cols]
df_results = df_results[first_cols+last_cols]
df_results = df_results.query("date > '2022-04-22'")
df_results = df_results.sort_values(by=['ds_name', 'max_candidates', 'beam_sz', 'datetime'])
display_all(df_results)
# Out:
#              datetime        date    time          ds_name  split  \
# 7   2022-04-28_115012  2022-04-28  115012  rotten_tomatoes  valid
# 11  2022-04-29_101822  2022-04-29  101822  rotten_tomatoes  valid
# 9   2022-04-28_193846  2022-04-28  193846  rotten_tomatoes  valid
# 13  2022-04-29_215612  2022-04-29  215612  rotten_tomatoes  valid
# 8   2022-04-28_135009  2022-04-28  135009  rotten_tomatoes  valid
# 12  2022-04-29_144728  2022-04-29  144728  rotten_tomatoes  valid
# 10  2022-04-28_232643  2022-04-28  232643  rotten_tomatoes  valid
# 14  2022-04-30_071723  2022-04-30  071723  rotten_tomatoes  valid
#
#                     attack_name  num_examples  beam_sz  max_candidates  \
# 7   BeamSearchCFEmbeddingAttack            -1        2               5
# 11           BeamSearchLMAttack            -1        2               5
# 9   BeamSearchCFEmbeddingAttack            -1        5               5
# 13           BeamSearchLMAttack            -1        5               5
# 8   BeamSearchCFEmbeddingAttack            -1        2              25
# 12           BeamSearchLMAttack            -1        2              25
# 10  BeamSearchCFEmbeddingAttack            -1        5              25
# 14           BeamSearchLMAttack            -1        5              25
#
#     sts_threshold  contradiction_threshold  successful_attacks  \
# 7             0.9                      0.1                 574
# 11            0.9                      0.1                 457
# 9             0.9                      0.1                 596
# 13            0.9                      0.1                 491
# 8             0.9                      0.1                 755
# 12            0.9                      0.1                 655
# 10            0.9                      0.1                 765
# 14            0.9                      0.1                 681
#
#     failed_attacks  skipped_attacks  original_accuracy  attack_accuracy_perc  \
# 7              321              171              83.96                 30.11
# 11             438              171              83.96                 41.09
# 9              299              171              83.96                 28.05
# 13             404              171              83.96                 37.90
# 8              140              171              83.96                 13.13
# 12             240              171              83.96                 22.51
# 10             130              171              83.96                 12.20
# 14             214              171              83.96                 20.08
#
#     attack_success_rate  avg_word_perturbed  avg_word_perturbed_perc  \
# 7                 64.13               18.53                    13.08
# 11                51.06               18.53                    11.25
# 9                 66.59               18.53                    13.59
# 13                54.86               18.53                    11.64
# 8                 84.36               18.53                    11.38
# 12                73.18               18.53                    10.60
# 10                85.47               18.53                    11.44
# 14                76.09               18.53                    10.79
#
#     max_words_changed  avg_num_queries  avg_original_perplexity  \
# 7                  11           172.49                    67.65
# 11                 10           115.25                    70.66
# 9                  11           365.80                    68.67
# 13                 12           235.94                    70.25
# 8                  10           485.07                    67.61
# 12                 12           372.58                    68.31
# 10                 10           923.93                    67.49
# 14                 10           701.42                    67.80
#
#     avg_attack_perplexity  avg_attack_use_score  label_flip_mean  \
# 7                  116.57                  0.87         0.641341
# 11                  81.40                  0.86         0.510615
# 9                  120.00                  0.87         0.665922
# 13                  81.82                  0.86         0.548603
# 8                  115.86                  0.87         0.843575
# 12                  87.36                  0.87         0.731844
# 10                 115.39                  0.87         0.854749
# 14                  87.36                  0.86         0.760894
#
#     vm_scores_mean  sts_scores_mean  contradiction_scores_mean  \
# 7         0.358092         0.937195                   0.007375
# 11        0.291697         0.935593                   0.013248
# 9         0.365898         0.937735                   0.007684
# 13        0.309664         0.936044                   0.012935
# 8         0.507004         0.943650                   0.010738
# 12        0.441303         0.941105                   0.017361
# 10        0.514595         0.943978                   0.011258
# 14        0.458730         0.941298                   0.018023
#
#     sts_threshold_met_mean  contradiction_threshold_met_mean  vm_scores_std  \
# 7                      1.0                               1.0       0.236130
# 11                     1.0                               1.0       0.247332
# 9                      1.0                               1.0       0.237334
# 13                     1.0                               1.0       0.250390
# 8                      1.0                               1.0       0.226536
# 12                     1.0                               1.0       0.249102
# 10                     1.0                               1.0       0.224435
# 14                     1.0                               1.0       0.247892
#
#     vm_scores_10%  vm_scores_25%  vm_scores_50%  vm_scores_75%  vm_scores_90%  \
# 7        0.020354       0.134861       0.384076       0.537604       0.661171
# 11       0.003034       0.046361       0.282425       0.489447       0.638843
# 9        0.019653       0.138447       0.410889       0.544093       0.668929
# 13       0.004225       0.050859       0.316473       0.508921       0.659766
# 8        0.132420       0.395013       0.539291       0.677373       0.778020
# 12       0.023104       0.266166       0.488348       0.638876       0.730486
# 10       0.142345       0.402583       0.552056       0.683690       0.779649
# 14       0.025798       0.316594       0.507847       0.654339       0.743308
#
#     sts_scores_std  sts_scores_10%  sts_scores_25%  sts_scores_50%  \
# 7         0.032504        0.901773        0.906033        0.928487
# 11        0.032838        0.901792        0.905584        0.925070
# 9         0.032276        0.901888        0.907091        0.929430
# 13        0.032623        0.902018        0.906116        0.926615
# 8         0.032028        0.902258        0.911698        0.942714
# 12        0.032735        0.902240        0.909144        0.936791
# 10        0.031876        0.902607        0.912444        0.942391
# 14        0.032435        0.902575        0.910298        0.937015
#
#     sts_scores_75%  sts_scores_90%  contradiction_scores_std  \
# 7         0.967186        0.986734                  0.014859
# 11        0.963499        0.988796                  0.021698
# 9         0.967255        0.986843                  0.015006
# 13        0.962620        0.989048                  0.020865
# 8         0.973173        0.988487                  0.018566
# 12        0.969982        0.989072                  0.023444
# 10        0.973365        0.988487                  0.019507
# 14        0.969676        0.989072                  0.024308
#
#     contradiction_scores_10%  contradiction_scores_25%  \
# 7                   0.000363                  0.000641
# 11                  0.000436                  0.000925
# 9                   0.000359                  0.000640
# 13                  0.000450                  0.000954
# 8                   0.000439                  0.000837
# 12                  0.000614                  0.001525
# 10                  0.000432                  0.000830
# 14                  0.000582                  0.001463
#
#     contradiction_scores_50%  contradiction_scores_75%  \
# 7                   0.001530                  0.005971
# 11                  0.003163                  0.014227
# 9                   0.001592                  0.006573
# 13                  0.003225                  0.013853
# 8                   0.002342                  0.011060
# 12                  0.005588                  0.025851
# 10                  0.002522                  0.011559
# 14                  0.005740                  0.026320
#
#     contradiction_scores_90%
# 7                   0.020951
# 11                  0.043108
# 9                   0.021924
# 13                  0.042566
# 8                   0.032837
# 12                  0.054772
# 10                  0.035017
# 14                  0.057393

# %%
df_results[['datetime','attack_name', 'max_candidates', 'beam_sz', 'label_flip_mean','vm_scores_mean', 'sts_scores_mean', 'contradiction_scores_mean']]
# Out:
#              datetime                  attack_name  max_candidates  beam_sz  \
# 7   2022-04-28_115012  BeamSearchCFEmbeddingAttack               5        2
# 11  2022-04-29_101822           BeamSearchLMAttack               5        2
# 9   2022-04-28_193846  BeamSearchCFEmbeddingAttack               5        5
# 13  2022-04-29_215612           BeamSearchLMAttack               5        5
# 8   2022-04-28_135009  BeamSearchCFEmbeddingAttack              25        2
# 12  2022-04-29_144728           BeamSearchLMAttack              25        2
# 10  2022-04-28_232643  BeamSearchCFEmbeddingAttack              25        5
# 14  2022-04-30_071723           BeamSearchLMAttack              25        5
#
#     label_flip_mean  vm_scores_mean  sts_scores_mean  \
# 7          0.641341        0.358092         0.937195
# 11         0.510615        0.291697         0.935593
# 9          0.665922        0.365898         0.937735
# 13         0.548603        0.309664         0.936044
# 8          0.843575        0.507004         0.943650
# 12         0.731844        0.441303         0.941105
# 10         0.854749        0.514595         0.943978
# 14         0.760894        0.458730         0.941298
#
#     contradiction_scores_mean
# 7                    0.007375
# 11                   0.013248
# 9                    0.007684
# 13                   0.012935
# 8                    0.010738
# 12                   0.017361
# 10                   0.011258
# 14                   0.018023

# %%
filename_run = "/data/tproth/travis_attack/baselines/2022-04-28_232643_rotten_tomatoes_valid_BeamSearchCFEmbeddingAttack_beam_sz=5_max_candidates=25_processed.csv"
df = pd.read_csv(filename_run)

# %%
display_all(df.sample(2))
# Out:
#      ground_truth_output  num_queries  original_output  original_score  \
# 550                  0.0        266.0              0.0        0.245339
# 387                  1.0        219.0              1.0        0.480720
#
#                                                                                                                  original_text  \
# 550    amid the shock and curiosity factors , the film is just a corny examination of a young actress trying to find her way .
# 387  although tender and touching , the movie would have benefited from a little more dramatic tension and some more editing .
#
#      perturbed_output  perturbed_score  \
# 550               1.0         0.589488
# 387               0.0         0.819396
#
#                                                                                                               perturbed_text  \
# 550  amid the shock and curiosity factors , the film is just a hokey examination of a young actress trying to find her way .
# 387     although tender and touching , the movie would have been from a little more dramatic tension and some more editing .
#
#     result_type  truelabel  orig_predclass  pp_predclass  \
# 550  Successful          0               0             1
# 387  Successful          1               1             0
#
#      orig_truelabel_probs  pp_truelabel_probs  vm_scores  label_flip  \
# 550               0.75466            0.410513   0.344147           1
# 387               0.51928            0.180605   0.338675           1
#
#      sts_scores  contradiction_scores  sts_threshold_met  \
# 550    0.977341              0.000486               True
# 387    0.972206              0.001476               True
#
#      contradiction_threshold_met
# 550                         True
# 387                         True

# %%
good_example_idxs = [360, 714, 247]
bad_example_idxs = [690,323,308]

display_all(df.iloc[bad_example_idxs])
# Out:
#      ground_truth_output  num_queries  original_output  original_score  \
# 690                  0.0       2068.0              0.0        0.062339
# 323                  1.0        151.0              1.0        0.212919
# 308                  1.0        907.0              1.0        0.042907
#
#                                                                                                      original_text  \
# 690  this little film is so slovenly done , so primitive in technique , that it can't really be called animation .
# 323                                                 may be more genial than ingenious , but it gets the job done .
# 308                                                          . . . bright , intelligent , and humanly funny film .
#
#      perturbed_output  perturbed_score  \
# 690               1.0         0.664022
# 323               0.0         0.896022
# 308               0.0         0.905542
#
#                                                                                                           perturbed_text  \
# 690  this little film is so slovenly accomplished , so elemental in technique , that it can't really be called abetted .
# 323                                                      may be more genial than ingenious , but it gets the job ended .
# 308                                                                  . . . radioactive , canny , and humanly joke film .
#
#     result_type  truelabel  orig_predclass  pp_predclass  \
# 690  Successful          0               0             1
# 323  Successful          1               1             0
# 308  Successful          1               1             0
#
#      orig_truelabel_probs  pp_truelabel_probs  vm_scores  label_flip  \
# 690              0.937661            0.335977   0.601683           1
# 323              0.787081            0.103978   0.683103           1
# 308              0.957093            0.094458   0.862635           1
#
#      sts_scores  contradiction_scores  sts_threshold_met  \
# 690    0.859913              0.363196               True
# 323    0.786201              0.643740               True
# 308    0.719449              0.015210               True
#
#      contradiction_threshold_met
# 690                         True
# 323                         True
# 308                         True
