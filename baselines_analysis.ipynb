# %%
# %load_ext autoreload
# %autoreload 2
# %load_ext line_profiler

# %%
import pandas as pd 
from travis_attack.utils import display_all

# %%
filename_results = f"/data/tproth/travis_attack/baselines/results.csv"
df_results = pd.read_csv(filename_results).sort_values(by=['ds_name', 'max_candidates', 'beam_sz'])
display_all(df_results)
# Out:
#             datetime          ds_name  split                  attack_name  \
# 0  2022-04-20_140812  rotten_tomatoes  valid  BeamSearchCFEmbeddingAttack
# 2  2022-04-20_190011  rotten_tomatoes  valid  BeamSearchCFEmbeddingAttack
# 5  2022-04-21_103040  rotten_tomatoes  valid           BeamSearchLMAttack
# 1  2022-04-20_152404  rotten_tomatoes  valid  BeamSearchCFEmbeddingAttack
# 4  2022-04-21_064434  rotten_tomatoes  valid           BeamSearchLMAttack
# 3  2022-04-20_215830  rotten_tomatoes  valid  BeamSearchCFEmbeddingAttack
# 6  2022-04-21_140144  rotten_tomatoes  valid           BeamSearchLMAttack
#
#    num_examples  beam_sz  max_candidates  sts_threshold  \
# 0            -1        2               5            0.6
# 2            -1        5               5            0.6
# 5            -1        5               5            0.6
# 1            -1        2              25            0.6
# 4            -1        2              25            0.6
# 3            -1        5              25            0.6
# 6            -1        5              25            0.6
#
#    contradiction_threshold  successful_attacks  failed_attacks  \
# 0                      0.8                 709             186
# 2                      0.8                 716             179
# 5                      0.8                 731             164
# 1                      0.8                 851              44
# 4                      0.8                 812              83
# 3                      0.8                 856              39
# 6                      0.8                 823              72
#
#    skipped_attacks  original_accuracy  attack_accuracy_perc  \
# 0              171              83.96                 17.45
# 2              171              83.96                 16.79
# 5              171              83.96                 15.38
# 1              171              83.96                  4.13
# 4              171              83.96                  7.79
# 3              171              83.96                  3.66
# 6              171              83.96                  6.75
#
#    attack_success_rate  avg_word_perturbed  avg_word_perturbed_perc  \
# 0                79.22               18.53                    15.89
# 2                80.00               18.53                    15.82
# 5                81.68               18.53                    14.51
# 1                95.08               18.53                    12.79
# 4                90.73               18.53                    11.79
# 3                95.64               18.53                    12.80
# 6                91.96               18.53                    11.75
#
#    max_words_changed  avg_num_queries  avg_original_perplexity  \
# 0                 12           216.17                    68.18
# 2                 12           462.64                    68.21
# 5                 15           333.87                    68.77
# 1                  9           602.74                    67.44
# 4                 10           500.85                    68.05
# 3                  9          1157.14                    67.49
# 6                 10           941.54                    67.84
#
#    avg_attack_perplexity  avg_attack_use_score  label_flip_mean  \
# 0                 126.22                  0.85         0.792179
# 2                 126.78                  0.85         0.800000
# 5                  84.14                  0.83         0.816760
# 1                 115.97                  0.86         0.950838
# 4                  88.03                  0.85         0.907263
# 3                 115.51                  0.86         0.956425
# 6                  88.14                  0.85         0.919553
#
#    vm_scores_mean  sts_scores_mean  contradiction_scores_mean  \
# 0        0.440802         0.871122                   0.063001
# 2        0.444756         0.873258                   0.067944
# 5        0.471426         0.843651                   0.188115
# 1        0.583991         0.894298                   0.107326
# 4        0.562336         0.872557                   0.216564
# 3        0.588675         0.893716                   0.108018
# 6        0.575192         0.876127                   0.224724
#
#    sts_threshold_met_mean  contradiction_threshold_met_mean  vm_scores_std  \
# 0                     1.0                               1.0       0.214919
# 2                     1.0                               1.0       0.212365
# 5                     1.0                               1.0       0.234595
# 1                     1.0                               1.0       0.188164
# 4                     1.0                               1.0       0.210030
# 3                     1.0                               1.0       0.187663
# 6                     1.0                               1.0       0.207120
#
#    vm_scores_10%  vm_scores_25%  vm_scores_50%  vm_scores_75%  vm_scores_90%  \
# 0       0.109702       0.289065       0.464150       0.595906       0.704511
# 2       0.118395       0.304458       0.466470       0.596376       0.706133
# 5       0.068291       0.347062       0.501473       0.646368       0.756472
# 1       0.345873       0.464215       0.601123       0.733893       0.807610
# 4       0.274106       0.454525       0.595151       0.722007       0.801031
# 3       0.352577       0.469456       0.611079       0.735899       0.811927
# 6       0.314590       0.465846       0.607644       0.733659       0.812537
#
#    sts_scores_std  sts_scores_10%  sts_scores_25%  sts_scores_50%  \
# 0        0.111511        0.687978        0.803350        0.904476
# 2        0.109126        0.695565        0.807090        0.903979
# 5        0.120751        0.647268        0.752236        0.872387
# 1        0.099945        0.733249        0.846934        0.931583
# 4        0.111330        0.690140        0.809077        0.911326
# 3        0.100739        0.727172        0.848172        0.931583
# 6        0.107432        0.699178        0.813736        0.911473
#
#    sts_scores_75%  sts_scores_90%  contradiction_scores_std  \
# 0        0.962800        0.985733                  0.150880
# 2        0.963411        0.985733                  0.161689
# 5        0.950311        0.979675                  0.248127
# 1        0.971827        0.987493                  0.203749
# 4        0.962221        0.984328                  0.269267
# 3        0.972116        0.987493                  0.204711
# 6        0.962663        0.984749                  0.272088
#
#    contradiction_scores_10%  contradiction_scores_25%  \
# 0                  0.000412                  0.000811
# 2                  0.000412                  0.000811
# 5                  0.000851                  0.003727
# 1                  0.000535                  0.001200
# 4                  0.001072                  0.005200
# 3                  0.000541                  0.001163
# 6                  0.001072                  0.005180
#
#    contradiction_scores_50%  contradiction_scores_75%  \
# 0                  0.002979                  0.024157
# 2                  0.003007                  0.023523
# 5                  0.041751                  0.327282
# 1                  0.006188                  0.076437
# 4                  0.056746                  0.437869
# 3                  0.006177                  0.078434
# 6                  0.059113                  0.452033
#
#    contradiction_scores_90%
# 0                  0.225253
# 2                  0.252246
# 5                  0.645281
# 1                  0.467806
# 4                  0.694113
# 3                  0.468565
# 6                  0.696440

# %%
df_results[['attack_name', 'max_candidates', 'beam_sz', 'label_flip_mean','vm_scores_mean', 'sts_scores_mean', 'contradiction_scores_mean']]
# Out:
#                    attack_name  max_candidates  beam_sz  label_flip_mean  \
# 0  BeamSearchCFEmbeddingAttack               5        2         0.792179
# 2  BeamSearchCFEmbeddingAttack               5        5         0.800000
# 5           BeamSearchLMAttack               5        5         0.816760
# 1  BeamSearchCFEmbeddingAttack              25        2         0.950838
# 4           BeamSearchLMAttack              25        2         0.907263
# 3  BeamSearchCFEmbeddingAttack              25        5         0.956425
# 6           BeamSearchLMAttack              25        5         0.919553
#
#    vm_scores_mean  sts_scores_mean  contradiction_scores_mean
# 0        0.440802         0.871122                   0.063001
# 2        0.444756         0.873258                   0.067944
# 5        0.471426         0.843651                   0.188115
# 1        0.583991         0.894298                   0.107326
# 4        0.562336         0.872557                   0.216564
# 3        0.588675         0.893716                   0.108018
# 6        0.575192         0.876127                   0.224724

# %%
filename_run = "/data/tproth/travis_attack/baselines/2022-04-20_215830_rotten_tomatoes_valid_BeamSearchCFEmbeddingAttack_beam_sz=5_max_candidates=25_processed.csv"
df = pd.read_csv(filename_run)

# %%
display_all(df.sample(2))
# Out:
#      ground_truth_output  num_queries  original_output  original_score  \
# 288                  1.0        291.0              1.0        0.084695
# 308                  1.0        907.0              1.0        0.042907
#
#                                                                                                                     original_text  \
# 288  late marriage is an in-your-face family drama and black comedy that is filled with raw emotions conveying despair and love .
# 308                                                                         . . . bright , intelligent , and humanly funny film .
#
#      perturbed_output  perturbed_score  \
# 288               0.0         0.802962
# 308               0.0         0.905542
#
#                                                                                                                      perturbed_text  \
# 288  late marriage is an in-your-face family drama and black comedy that is filled with gross emotions conveying despair and love .
# 308                                                                             . . . radioactive , canny , and humanly joke film .
#
#     result_type  truelabel  orig_predclass  pp_predclass  \
# 288  Successful          1               1             0
# 308  Successful          1               1             0
#
#      orig_truelabel_probs  pp_truelabel_probs  vm_scores  label_flip  \
# 288              0.915305            0.197038   0.718266           1
# 308              0.957093            0.094458   0.862635           1
#
#      sts_scores  contradiction_scores  sts_threshold_met  \
# 288    0.992543              0.005673               True
# 308    0.719449              0.015210               True
#
#      contradiction_threshold_met
# 288                         True
# 308                         True

# %%
good_example_idxs = [360, 714, 247]
bad_example_idxs = [690,323,308]

display_all(df.iloc[[106, 360, 714]])
# Out:
#      ground_truth_output  num_queries  original_output  original_score  \
# 106                  1.0        270.0              1.0        0.186376
# 360                  1.0        125.0              1.0        0.337630
# 714                  0.0        123.0              0.0        0.094781
#
#                                                                                                          original_text  \
# 106  highly irritating at first , mr . koury's passive technique eventually begins to yield some interesting results .
# 360                                                            for the most part , the film does hold up pretty well .
# 714                                                 the film's most improbable feat ? it didn't go straight to video .
#
#      perturbed_output  perturbed_score  \
# 106               0.0         0.925236
# 360               0.0         0.845042
# 714               1.0         0.606218
#
#                                                                                                        perturbed_text  \
# 106  highly irritating at first , mr . koury's passive technique eventually begins to yield some outlandish results .
# 360                                                       for the most part , the film does hold up pretty verywell .
# 714                                              the film's most improbable feat ? it didn't skip straight to video .
#
#     result_type  truelabel  orig_predclass  pp_predclass  \
# 106  Successful          1               1             0
# 360  Successful          1               1             0
# 714  Successful          0               0             1
#
#      orig_truelabel_probs  pp_truelabel_probs  vm_scores  label_flip  \
# 106              0.813624            0.074764   0.738859           1
# 360              0.662370            0.154959   0.507412           1
# 714              0.905219            0.393781   0.511437           1
#
#      sts_scores  contradiction_scores  sts_threshold_met  \
# 106    0.973442              0.005250               True
# 360    0.922146              0.000131               True
# 714    0.980738              0.000901               True
#
#      contradiction_threshold_met
# 106                         True
# 360                         True
# 714                         True
